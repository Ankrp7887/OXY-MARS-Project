# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/bajaj-finance-limited-443899-jobs-career?searchId=0b939265-0c73-4cba-9b10-eeedb824c3de']

#'Enter .CSV filename. ie, short Company name :       
filename = 'bajaj.csv'     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = 'Bajaj Finance Limited' 

#'Check total number of jobs and enter here :
total_jobs = 19

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/am-tech-networks-340886-jobs-career?searchId=ff25518c-28e6-4b5d-afd6-998bfec5a24b']

#'Enter .CSV filename. ie, short Company name :       
filename = 'amtn.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'amtechnetworksjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'amtnet'                       

#'Enter Company name :                                                                                                                      
company_name = 'Am Tech Networks' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/axel-technologies-private-limited-226645-jobs-career?searchId=ecf96495-ea8a-4e38-9e33-e3b45067176d']

#'Enter .CSV filename. ie, short Company name :       
filename = 'axeltech.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'axeltechnologiesprivatelimitedjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'axeltech'                       

#'Enter Company name :                                                                                                                      
company_name = 'Axel Technologies Private Limited' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/burgeon-it-services-pty-ltd-182443-jobs-career?searchId=1a28efa7-4a64-42da-8e4e-ee62b39f049e']

#'Enter .CSV filename. ie, short Company name :       
filename = 'bitserv.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'burgeonitservicesptyltdjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'bitserv'                       

#'Enter Company name :                                                                                                                      
company_name = 'Burgeon It Services Pty Ltd' 

#'Check total number of jobs and enter here :
total_jobs = 9

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

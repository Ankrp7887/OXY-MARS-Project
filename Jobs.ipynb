# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/arokee-online-solutions-private-limited-533040-jobs-career?searchId=97194048-9d2d-4e8a-a57e-7a97d31f73ef']

#'Enter .CSV filename. ie, short Company name :       
filename = 'ark.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'arokeeonlinesolutionsprivatelimitedjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'arokosol'                       

#'Enter Company name :                                                                                                                      
company_name = 'Arokee Online Solutions' 

#'Check total number of jobs and enter here :
total_jobs = 19

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/am-tech-networks-340886-jobs-career?searchId=ff25518c-28e6-4b5d-afd6-998bfec5a24b']

#'Enter .CSV filename. ie, short Company name :       
filename = 'amtn.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'amtechnetworksjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'amtnet'                       

#'Enter Company name :                                                                                                                      
company_name = 'Am Tech Networks' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/axel-technologies-private-limited-226645-jobs-career?searchId=ecf96495-ea8a-4e38-9e33-e3b45067176d']

#'Enter .CSV filename. ie, short Company name :       
filename = 'axeltech.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'axeltechnologiesprivatelimitedjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'axeltech'                       

#'Enter Company name :                                                                                                                      
company_name = 'Axel Technologies Private Limited' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/burgeon-it-services-pty-ltd-182443-jobs-career?searchId=1a28efa7-4a64-42da-8e4e-ee62b39f049e']

#'Enter .CSV filename. ie, short Company name :       
filename = 'bitserv.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'burgeonitservicesptyltdjobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'bitserv'                       

#'Enter Company name :                                                                                                                      
company_name = 'Burgeon It Services Pty Ltd' 

#'Check total number of jobs and enter here :
total_jobs = 26

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/citi-441847-jobs-career?searchId=faba9c27-e78e-4326-b166-3b8c8f8915ed']

#'Enter .CSV filename. ie, short Company name :       
filename = 'Citi.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'citijobsandcareer@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'citi'                       

#'Enter Company name :                                                                                                                      
company_name = 'Citi' 

#'Check total number of jobs and enter here :
total_jobs = 2454

# %%
#'Enter Main Company link(Having 25 entries each) :
complink = ['https://www.monsterindia.com/search/neo-sense-vector-technology-private-limited-503727-jobs-career?searchId=db84723c-51fd-4461-bbeb-b84afa442ef9']

#'Enter .CSV filename. ie, short Company name :      
filename = 'neosensevector.csv'    

#'Enter given email address :                                                                                                                                      
email_address = 'neosensevectortechnologyprivatelimitedjobsandcareers@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                  
username = 'neosense'                      

#'Enter Company name :                                                                                                                      
company_name = 'Neo Sense Vector Technology Private Limited'

#'Check total number of jobs and enter here :
total_jobs = 7

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/nandu-chemicals-private-limited-516125-jobs-career?searchId=eb831335-324c-4f26-b1c1-f584f42421d7']

#'Enter .CSV filename. ie, short Company name :       
filename = 'nanduche.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'nanduchemicalsprivatelimitedjobsandcareers@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'nanduche'                       

#'Enter Company name :                                                                                                                      
company_name = 'Nandu Chemicals Private Limited' 

#'Check total number of jobs and enter here :
total_jobs = 2

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/netquo-services-private-limited-515964-jobs-career?searchId=5dce5818-ec81-4cb1-ac62-211e4e5a407a']

#'Enter .CSV filename. ie, short Company name :       
filename = 'netqser.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'netquoservicesprivatelimitedjobsandcareers@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'netqser'                       

#'Enter Company name :                                                                                                                      
company_name = 'Netquo Services Private Limited' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/paypal-442010-jobs-career?searchId=197a490d-57a4-4bd5-8e6b-836494648fce']

#'Enter .CSV filename. ie, short Company name :       
filename = 'paypal.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'paypaljobsandcareers@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'paypal'                       

#'Enter Company name :                                                                                                                      
company_name = 'Paypal' 

#'Check total number of jobs and enter here :
total_jobs = 336

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/quess-corp-limited-327314-jobs-career?searchId=5b9403e1-419e-4bcf-8921-281736e55c9b']

#'Enter .CSV filename. ie, short Company name :       
filename = 'quessc.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'quessCorpLimited@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'quessc'                       

#'Enter Company name :                                                                                                                      
company_name = 'Quess Corp Limited' 

#'Check total number of jobs and enter here :
total_jobs = 28

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['https://www.monsterindia.com/search/rakuten-india-enterprises-private-limited-363509-jobs-career?searchId=880c0490-cf1c-4e3d-8ab7-f1bcd4455b79']

#'Enter .CSV filename. ie, short Company name :       
filename = 'rakuten.csv'     

#'Enter given email address :                                                                                                                                       
email_address = 'rakutenindiaenterprisesprivatelimited@sunisbrite.com'      

#'Enter Company UserName you entered :                                                                                   
username = 'rakuten'                       

#'Enter Company name :                                                                                                                      
company_name = 'Rakuten India Enterprises Private Limited' 

#'Check total number of jobs and enter here :
total_jobs = 81

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1

# %%
#'Enter Main Company link(Having 25 entries each) : 
complink = ['']

#'Enter .CSV filename. ie, short Company name :       
filename = ''     

#'Enter given email address :                                                                                                                                       
email_address = ''      

#'Enter Company UserName you entered :                                                                                   
username = ''                       

#'Enter Company name :                                                                                                                      
company_name = '' 

#'Check total number of jobs and enter here :
total_jobs = 1
